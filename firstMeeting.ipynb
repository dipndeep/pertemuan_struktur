# %% [markdown]
# # Pengantar Python untuk Pemula dari Pascal
#
# Selamat datang! Jika Anda sebelumnya belajar algoritma pemrograman dasar dengan Pascal, Python akan terasa lebih sederhana dan fleksibel. Berikut adalah beberapa perbedaan utama:
#
# - **Tidak perlu deklarasi tipe**: Di Pascal, Anda harus mendeklarasikan `var x: integer;`, tapi di Python cukup `x = 10`.
# - **Indentasi penting**: Blok kode (seperti dalam if atau loop) ditentukan oleh indentasi, bukan `begin...end`.
# - **Sintaks lebih ringkas**: Tidak ada titik koma di akhir baris, dan banyak hal yang lebih sederhana.
#
# Mari kita mulai dengan dasar-dasar!

# %% [markdown]
# ## 1. Output Dasar (Print)
#
# Di Pascal, Anda menggunakan `writeln('Hello World');`. Di Python, gunakan `print()`.

# %%
# Contoh print
print("Hello World!")
print('Hello World!')

print("123456")
print(123456)
# Out:
# Hello World!
# Hello World!
# 123456
# 123456

# %% [markdown]
# ## 2. Variabel dan Tipe Data
#
# Di Python, variabel tidak perlu dideklarasikan tipe. Python otomatis menentukan tipe berdasarkan nilai yang diberikan.
#
# Tipe data dasar:
# - `int`: bilangan bulat (seperti integer di Pascal)
# - `float`: bilangan desimal
# - `str`: string (teks)
# - `bool`: boolean (True/False)

# %%
# Contoh variabel
# myFirstName = "Ganendra"
# mySecondName = "Pradipa"

nama = "Ganendra Pratama"  # string
umur = 20  # integer
tinggi = 170.5  # float
status_mahasiswa = True  # boolean
nilai_ujian = "99"

print("Nama:", nama)
print("Umur:", umur)
print("Tinggi:", tinggi)
print("Mahasiswa:", status_mahasiswa)

# Cek tipe data
print("Tipe nama:", type(nama))
print("Tipe umur:", type(umur))
print("Tipe tinggi:", type(tinggi))
print("Tipe mahasiswa:", type(status_mahasiswa)) 
print("Tipe nilai ujian:", type(nilai_ujian))
# Out:
# Nama: Ganendra Pratama
# Umur: 20
# Tinggi: 170.5
# Mahasiswa: True
# Tipe nama: <class 'str'>
# Tipe umur: <class 'int'>
# Tipe tinggi: <class 'float'>
# Tipe mahasiswa: <class 'bool'>
# Tipe nilai ujian: <class 'str'>

# %% [markdown]
# ## 3. Operator
#
# Operator di Python mirip dengan Pascal:
# - Aritmatika: `+`, `-`, `*`, `/`, `//` (pembagian bulat), `%` (modulo)
# - Perbandingan: `==`, `!=`, `<`, `>`, `<=`, `>=`
# - Logika: `and`, `or`, `not` (bukan `and`, `or`, `not` seperti di Pascal)

# %%
# Contoh operator aritmatika
a = 10
b = 3
c = 9
print("Penjumlahan:", a + b)
print("Pengurangan:", a - b)
print("Perkalian:", a * b)
print("Pembagian:", a / b)
print("Pembagian bulat:", a // b)
print("Modulo:", a % b)

# Perbandingan
print("a > b:", a > b)
print("a == b:", a == b)
print("a != c:", a != c)

# Logika
x = False
y = False
print("x and y:", x and y)
print("x or y:", x or y)
print("not x:", not x)
# Out:
# Penjumlahan: 13
# Pengurangan: 7
# Perkalian: 30
# Pembagian: 3.3333333333333335
# Pembagian bulat: 3
# Modulo: 1
# a > b: True
# a == b: False
# a != c: True
# x and y: False
# x or y: False
# not x: True

# %% [markdown]
# ## 4. Struktur Kontrol: If-Else
#
# Di Python, if-else menggunakan indentasi. Tidak ada `then` atau `begin...end`.
#
# Sintaks:
# ```python
# if kondisi:
#     # kode jika benar
# elif kondisi_lain:
#     # kode jika kondisi_lain benar
# else:
#     # kode jika semua salah
# ```

# %%
# Contoh if-else
nilai = 85

if nilai >= 90:
    print("Grade: A")
elif nilai >= 80:
    print("Grade: B")
elif nilai >= 70:
    print("Grade: C")
else:
    print("Grade: D")

# Contoh nested if
umur = 18
if umur >= 17:
    if umur >= 21:
        print("Bisa mengemudi dan minum alkohol")
    else:
        print("Bisa mengemudi tapi tidak boleh minum alkohol")
else:
    print("Belum bisa mengemudi")

# %%
nilai = 80

if nilai >= 75:
    status = "Lulus"
else:
    status = "Tidak Lulus"

print("Nilai:", nilai)
print("Status:", status)

# %% [markdown]
# ## 5. Loop: For dan While
#
# - **For loop**: Untuk iterasi melalui sequence (list, range, dll.)
# - **While loop**: Loop selama kondisi benar
#
# Sintaks for:
# ```python
# for item in sequence:
#     # kode
# ```
#
# Sintaks while:
# ```python
# while kondisi:
#     # kode
# ```

# %%
print("\nFor loop dengan list:")
buah = ["apel", "jeruk", "mangga"]
for item in buah:
    print("Saya suka", item)
# Out:
# For loop dengan list:
# Saya suka apel
# Saya suka jeruk
# Saya suka mangga

# %%
buah.append("pinang")
for item in buah:
    print("Saya suka", item)

# %%
# Contoh for loop
print("For loop dengan range:")
for i in range(1, 6):  # 1 sampai 5
    print("Iterasi ke-", i)

print("\nFor loop dengan list:")
buah = ["apel", "jeruk", "mangga"]
for item in buah:
    print("Saya suka", item)

# Contoh while loop
print("\nWhile loop:")
count = 1
while count <= 5:
    print("Count:", count)
    count += 1  # increment

# Loop dengan break
print("\nLoop dengan break:")
for i in range(10):
    if i == 5:
        break
    print(i)

# %% [markdown]
# ## 6. Fungsi
#
# Fungsi didefinisikan dengan `def`. Mirip dengan procedure di Pascal tapi bisa mengembalikan nilai.
#
# Sintaks:
# ```python
# def nama_fungsi(parameter):
#     # kode
#     return nilai  # opsional
# ```

# %%
# Contoh fungsi sederhana
def sapa(nama):
    return "Halo, saya " + nama + "!. Salam kenal ya!"

hasil = sapa("Ganendra")
hasil2 = sapa("Dipa Ganendra")
print(hasil)
print(hasil2)

# %%
panjang = 5
lebar = 3
luas = panjang * lebar
print("Luas persegi panjang:", luas)

# %%
# Fungsi dengan multiple parameter
def hitung_luas_persegi(panjang, lebar):
    return panjang * lebar

luas = hitung_luas_persegi(5, 3)
luas1 = hitung_luas_persegi(10, 89)
print("Luas persegi panjang:", luas)
print("Luas persegi panjang:", luas1)

# %%
# Fungsi tanpa return (seperti procedure)
def cetak_info(nama, umur):
    print(f"Nama: {nama}, \nUmur: {umur}")

cetak_info("Pratama", 20)

# %% [markdown]
# ## 7. List (Array Dinamis)
#
# List di Python seperti array tapi lebih fleksibel. Tidak perlu mendeklarasikan ukuran.
#
# Sintaks:
# ```python
# daftar = [item1, item2, item3]
# ```

# %%
nilaiMahasiswa = [85, 90, 78, 92, 88, 95, 92]

# --- READ DATA ---
print("Nilai mahasiswa:", nilaiMahasiswa)
print(f"Nilai mahasiswa: {nilaiMahasiswa}")

# --- ADD DATA ---
print(f"\nNilai mahasiswa sebelum ditambahkan: {nilaiMahasiswa}")
nilaiMahasiswa.append(91)
print(f"Nilai mahasiswa setelah append: {nilaiMahasiswa}")
nilaiMahasiswa.extend([89, 87])
print(f"Nilai mahasiswa setelah extend: {nilaiMahasiswa}")
nilaiMahasiswa.insert(2, 80)
print(f"Nilai mahasiswa setelah insert: {nilaiMahasiswa}")

# --- UPDATE DATA ---
print(f"\nNilai mahasiswa sebelum update: {nilaiMahasiswa}")
nilaiMahasiswa[3] = 0
print(f"Nilai mahasiswa setelah update: {nilaiMahasiswa}")

# --- DELETE DATA ---
print(f"\nNilai mahasiswa sebelum delete: {nilaiMahasiswa}")
nilaiMahasiswa.remove(0)
print(f"Nilai mahasiswa setelah remove: {nilaiMahasiswa}")
nilaiMahasiswa.pop(2)
print(f"Nilai mahasiswa setelah pop: {nilaiMahasiswa}")
nilaiMahasiswa.pop()
print(f"Nilai mahasiswa setelah pop terakhir: {nilaiMahasiswa}")
del nilaiMahasiswa[7]
print(f"Nilai mahasiswa setelah del: {nilaiMahasiswa}")
# Out:
# Nilai mahasiswa: [85, 90, 78, 92, 88, 95, 92]
# Nilai mahasiswa: [85, 90, 78, 92, 88, 95, 92]
#
# Nilai mahasiswa sebelum ditambahkan: [85, 90, 78, 92, 88, 95, 92]
# Nilai mahasiswa setelah append: [85, 90, 78, 92, 88, 95, 92, 91]
# Nilai mahasiswa setelah extend: [85, 90, 78, 92, 88, 95, 92, 91, 89, 87]
# Nilai mahasiswa setelah insert: [85, 90, 80, 78, 92, 88, 95, 92, 91, 89, 87]
#
# Nilai mahasiswa sebelum update: [85, 90, 80, 78, 92, 88, 95, 92, 91, 89, 87]
# Nilai mahasiswa setelah update: [85, 90, 80, 0, 92, 88, 95, 92, 91, 89, 87]
#
# Nilai mahasiswa sebelum delete: [85, 90, 80, 0, 92, 88, 95, 92, 91, 89, 87]
# Nilai mahasiswa setelah remove: [85, 90, 80, 92, 88, 95, 92, 91, 89, 87]
# Nilai mahasiswa setelah pop: [85, 90, 92, 88, 95, 92, 91, 89, 87]
# Nilai mahasiswa setelah pop terakhir: [85, 90, 92, 88, 95, 92, 91, 89]
# Nilai mahasiswa setelah del: [85, 90, 92, 88, 95, 92, 91]

# %%
ukuranSepatu = [40, 41, 42, 43, 44, 42, 50, 41]
ukuranSepatu.remove(42)
print(f"Ukuran sepatu setelah remove: {ukuranSepatu}")

ukuranSepatu.remove(41)
print(f"Ukuran sepatu setelah remove 41: {ukuranSepatu}")
# Out:
# Ukuran sepatu setelah remove: [40, 41, 43, 44, 42, 50, 41]
# Ukuran sepatu setelah remove 41: [40, 43, 44, 42, 50, 41]

# %%
nilaiMahasiswa.append(67)
print("Nilai Mahasiswa setelah ditambahkan:", nilaiMahasiswa)

# %%
mahasiswaSisfo = ["Dipa", "Ganendra", "Pradipa", "Tegar"]
print ("Nama Mahasiswa Sistem Informasi:", mahasiswaSisfo)

mahasiswaSisfo.append("Pratama")
print ("Nama Mahasiswa Setelah ditambah:", mahasiswaSisfo)
print ("Nama Mahasiswa index 3:", mahasiswaSisfo[3])

# %%
nilaiMahasiswa.append(67)
print("Nilai Mahasiswa setelah ditambahkan:", nilaiMahasiswa)

# %%
nilaiMahasiswa[2]= 80
print("Nilai Mahasiswa setelah diubah:", nilaiMahasiswa)
print("Nilai Mahasiswa:", nilaiMahasiswa[2])

# %%
nilaiMahasiswa.pop()
print("Nilai Mahasiswa setelah dihapus:", nilaiMahasiswa)

# %%
nilaiMahasiswa.pop()
print("Nilai Mahasiswa setelah dihapus:", nilaiMahasiswa)

# %%
nilaiMahasiswa.remove(90)
print("Nilai Mahasiswa setelah dihapus:", nilaiMahasiswa)

# %%
# Contoh list
nilai_mahasiswa = [85, 90, 78, 92, 88]

print("List nilai:", nilai_mahasiswa)
print("Nilai pertama:", nilai_mahasiswa[0])  # indeks dimulai dari 0
print("Nilai terakhir:", nilai_mahasiswa[-1])  # indeks negatif untuk dari belakang

# Menambah item
nilai_mahasiswa.append(95)
print("Setelah append:", nilai_mahasiswa)

# Loop melalui list
print("Semua nilai:")
for nilai in nilai_mahasiswa:
    print(nilai)

# %%
# List comprehension (cara Pythonic untuk membuat list)
kuadrat = [x**2 for x in range(1, 6)]
print("Kuadrat 1-5:", kuadrat)

# %% [markdown]
# ## 8. Input dari Pengguna
#
# Untuk membaca input, gunakan `input()`. Di Pascal, ini seperti `readln()`.
#
# Sintaks:
# ```python
# nama = input("Masukkan nama: ")
# ```

# %%
# Contoh input
nama = input("Masukkan nama Anda: ")
umur = int(input("Masukkan umur Anda: "))  # konversi ke integer

print(f"Halo {nama}, umur Anda {umur} tahun.")
# Out:
# Halo Ganendra, umur Anda 10 tahun.

# %%
# Contoh input
nama = input("Masukkan nama Anda: ")
umur = int(input("Masukkan umur Anda: "))  # konversi ke integer

print("Halo ", nama, "umur Anda ", umur, "tahun.")
# Out:
# Halo  Ganendra umur Anda  10 tahun.

# %%
# Input dengan validasi sederhana
nilai = float(input("Masukkan nilai ujian (0-100): "))
if nilai >= 60:
    print(f"Lulus! dengan nilai {nilai}")
else:
    print(f"Belum lulus, coba lagi! Nilai Anda {nilai}")

# %% [markdown]
# ## Kesimpulan
#
# Ini adalah pengantar dasar Python untuk Anda yang sebelumnya belajar Pascal. Python lebih sederhana dalam banyak hal, tapi sangat powerful untuk berbagai aplikasi.
#
# Cobalah jalankan cell-cell di atas dan modifikasi kode untuk latihan. Jika ada pertanyaan, tanyakan saja!
#
# Selanjutnya, Anda bisa belajar tentang:
# - Dictionary dan Set
# - File I/O
# - Modules dan Packages
# - Object-Oriented Programming

# %%
mahasiswa = {
    "nama": "Ganendra Pratama",
    "nim": "202257201006",
    "semester": 4
}

print(mahasiswa)

print("Informasi Mahasiswa:")
print("Nama     :", mahasiswa["nama"])
print("NIM      :", mahasiswa["nim"])
print("Semester :", mahasiswa["semester"])

# %%
mahasiswa.update({"nama": "Ganendra Pradipa"})
print("Informasi Mahasiswa setelah diupdate:")
print("Nama    :", mahasiswa["nama"])
print("NIM     :", mahasiswa["nim"])

# %%
mahasiswa["jurusan"] = "Sistem Informasi"
print("Informasi Mahasiswa setelah ditambahkan jurusan:")
print("Nama    :", mahasiswa["nama"])
print("NIM     :", mahasiswa["nim"])
print("Jurusan :", mahasiswa["jurusan"])

# %%
mahasiswa.pop("nim")

print(mahasiswa)

print("\nInformasi Mahasiswa setelah dihapus NIM:")
print("Nama    :", mahasiswa["nama"])
print("Jurusan :", mahasiswa["jurusan"])

# %%
print(mahasiswa.keys())
print(mahasiswa.values())
print(mahasiswa.items())

# %%
umurMahasiswa = (20, 21, 22, 23, 24, 20, 21, 20)
print("Tuple umur mahasiswa:", umurMahasiswa)
print("Jumlah Mahasiswa dengan umur 20:", umurMahasiswa.count(20))
print("Umur mahasiswa 23 tahun ada di index :", umurMahasiswa.index(23))

# %%
umurMahasiswa = {24, 35, 56, 33, 17, 20}
print("Set umur mahasiswa:", umurMahasiswa)

umurMahasiswa.pop()
print(umurMahasiswa)

# %%
dataDiri = {
    "nama": "Ganendra Pratama",
    "nim": "202257201006",
    "jurusan": "Sistem Informasi",
    "angkatan": 2022,
    "semester": 4
}

print("Seluruh data diri:", dataDiri)
print("\nNama :", dataDiri["nama"])

dataDiri["semester"] = 8
dataDiri["alamat"] = "Jl. Mawar No. 123"

print("\nData diri setelah diupdate dan ditambahkan alamat:")
print("Nama     :", dataDiri["nama"])
print("NIM      :", dataDiri["nim"])
print("Jurusan  :", dataDiri["jurusan"])
print("Angkatan :", dataDiri["angkatan"])
print("Semester  :", dataDiri["semester"])
print("Alamat   :", dataDiri["alamat"])

# %%
nama = input("Masukkan nama Anda: ")
umur = int(input("Masukkan umur Anda: "))
nilai = float(input("Masukkan nilai ujian (0-100): "))

if nilai >= 80:
    status = "Grade A"
elif nilai >= 70:
    status = "Grade B"
elif nilai >= 60:
    status = "Grade C"
else:
    status = "Grade D"

print("Nama:", nama)
print("Umur:", umur)
print("Nilai:", nilai)
print("Status:", status)
# Out:
# Nama: Ganendra
# Umur: 20
# Nilai: 90.0
# Status: Grade A

# %% [markdown]
# # Soal Praktikum Nomor 1
#
# Buat program menggunakan **list** untuk menyimpan **5 nama mahasiswa** dengan ketentuan sebagai berikut:
#
# 1. Tampilkan seluruh data.
# 2. Tampilkan nama pertama dan nama terakhir.
# 3. Tambahkan 1 nama baru.
# 4. Hapus nama mahasiswa pada urutan ke-3.
# 5. Tampilkan hasil akhir.

# %%
nilaiMahasiswa = [85, 90, 78, 92, 88]
print("Nilai Mahasiswa:", nilaiMahasiswa)
# Out:
# Nilai Mahasiswa: [85, 90, 78, 92, 88]
