# %%
mahasiswaSisfo = ["Dipa", "Ganendra", "Pradipa", "Tegar"]
print ("Nama Mahasiswa Sistem Informasi:", mahasiswaSisfo)

mahasiswaSisfo.append("Fanny")
print ("Nama Mahasiswa Setelah ditambah:", mahasiswaSisfo)
print ("Nama Mahasiswa index 0:", mahasiswaSisfo[0])
# Out:
# Nama Mahasiswa Sistem Informasi: ['Dipa', 'Ganendra', 'Pradipa', 'Tegar']
# Nama Mahasiswa Setelah ditambah: ['Dipa', 'Ganendra', 'Pradipa', 'Tegar', 'Fanny']
# Nama Mahasiswa index 0: Dipa

# %%
dataDiri = {
    "nama": "Ganendra Pratama",
    "nim": "202257201006",
    "jurusan": "Sistem Informasi",
    "angkatan": 2022,
    "semester": 4
}

print("Seluruh data diri:", dataDiri)
print("\nNama :", dataDiri["nama"])

dataDiri["semester"] = 8
dataDiri["alamat"] = "Jl. Mawar No. 123"

print("\nData diri setelah diupdate dan ditambahkan alamat:")
print("Nama     :", dataDiri["nama"])
print("NIM      :", dataDiri["nim"])
print("Jurusan  :", dataDiri["jurusan"])
print("Angkatan :", dataDiri["angkatan"])
print("Semester :", dataDiri["semester"])
print("Alamat   :", dataDiri["alamat"])
# Out:
# Seluruh data diri: {'nama': 'Ganendra Pratama', 'nim': '202257201006', 'jurusan': 'Sistem Informasi', 'angkatan': 2022, 'semester': 4}
#
# Nama : Ganendra Pratama
#
# Data diri setelah diupdate dan ditambahkan alamat:
# Nama     : Ganendra Pratama
# NIM      : 202257201006
# Jurusan  : Sistem Informasi
# Angkatan : 2022
# Semester : 8
# Alamat   : Jl. Mawar No. 123
